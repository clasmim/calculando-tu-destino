# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("../web2/csv/BetterLifeRegions_clean.csv")
dv = pd.read_csv("../web2/csv/BetterLife.csv")
countries = df["Country"].values
df_mean = df.groupby("Country").mean()
df_mean = df_mean.merge(dv[["Country","Life satisfaction"]],on="Country",how="left")
df_mean.describe()
# Out:
#        Education       Jobs     Income     Safety     Health  Environment  \
# count  36.000000  36.000000  36.000000  36.000000  36.000000    36.000000
# mean    7.313369   6.834594   3.396558   9.160549   6.319969     6.791915
# std     2.560347   2.039538   1.993719   1.600356   2.713257     2.393771
# min     0.725000   2.050000   0.106250   3.466667   0.511111     0.414286
# 25%     7.122115   6.286285   2.322596   9.470000   4.783125     5.350000
# 50%     8.044712   7.345000   3.382353   9.732500   7.220000     7.283333
# 75%     8.965000   8.348750   3.972917   9.824760   8.353846     8.615625
# max     9.812500   9.366667   9.942857   9.950000   9.600000     9.940000
#
#        Civic engagement  Accessibility to services    Housing  Community  \
# count         36.000000                  36.000000  36.000000  36.000000
# mean           5.432358                   6.578132   4.629413   6.779681
# std            2.870681                   1.715184   2.491383   1.915630
# ...
